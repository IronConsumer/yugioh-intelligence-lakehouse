# %%
from src.utils.spark_manager import SparkManager

spark = SparkManager.get_session()

df = spark.read.format("delta").load("data/silver/cards")
df.show(5)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 25/12/30 09:33:58 WARN Utils: Your hostname, TDUPAS resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/12/30 09:33:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/tdupas/yugioh-intelligence/.venv/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/tdupas/.ivy2/cache
# The jars for the packages stored in: /home/tdupas/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-b744d62a-b879-4af1-b1b9-c9244946427c;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.0.0 in central
# 	found io.delta#delta-storage;3.0.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# ...

# %%
# %load_ext sql
# %sql duckdb:///:memory:
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml
# Connecting to 'duckdb:///:memory:'

# %%
# %%sql
# SELECT
#     *
# FROM
#     'data/gold/arbitrage_opportunities/*.parquet'
# WHERE
#     price_diff > 15 and price_diff <
#     AND price_tcg != 0
# ORDER BY
#     price_diff DESC
# ;
# Out:
# Running query in 'duckdb:///:memory:'
# +--------------------------------+-----------------+----------------+----------+-----------+------------+---------------+
# |              name              |       type      |   archetype    | price_cm | price_tcg | price_diff | price_gap_pct |
# +--------------------------------+-----------------+----------------+----------+-----------+------------+---------------+
# |          Blood Mefist          | Synchro Monster |      None      |  20.34   |  1800.00  |  1779.66   |     8749.6    |
# | Chimaera, the Master of Beasts |  Effect Monster |      None      |  103.44  |   600.00  |   496.56   |     480.0     |
# |      Anotherverse Dragon       |  Normal Monster |      None      |  30.00   |   381.20  |   351.20   |     1170.7    |
# |          Garma Sword           |  Ritual Monster |      None      |  104.08  |   369.99  |   265.91   |     255.5     |
# ...
